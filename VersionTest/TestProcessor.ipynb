# %%
# 모듈 불러오기
from data_processor import *
file_path = '../Datasets/validation.csv'

# %%
# 전처리 테스트
dataset = preprocessor(file_path)
dataset
# Out:
#      Amount  ExpectedRevenue  TotalOpportunityQuantity
# 0   3207480         641496.0                    4133.0
# 1   3464115        1732057.5                    5119.0
# 3    847450          84745.0                     997.0
# 4   2049800        1537350.0                    4457.0
# 5   2925000        2047500.0                    4842.0
# 6      7425              0.0                      33.0
# 7    582035          58203.5                    2684.0
# 8    281700         140850.0                    1811.0
# 9    283440              0.0                    2264.0
# 10  3915950         783190.0                    3552.0
# 11    89230           8923.0                    1427.0
# 13  2623525              0.0                    3129.0
# 14   605000         423500.0                    1210.0
# 15    65070              0.0                     723.0
# 18  1498260              0.0                    5302.0
# 19   488860         439974.0                    1029.0
# 20   857500         771750.0                     686.0
# 21   112725              0.0                     501.0
# 22  1755885              0.0                    2091.0
# 23  1528750         152875.0                    1223.0
# 24  4067300        3050475.0                    4372.0
# 25   276000              0.0                    2954.0
# 26   318600          31860.0                    1416.0
# 27    36960          18480.0                     924.0
# 28   679555         135911.0                    2824.0
# 29  1740500              0.0                    3481.0
# 30    41580              0.0                     462.0
# 31  2243150        1682362.5                    2128.0
# 32      680            340.0                      17.0
# 33  4708010         941602.0                    6546.0
# 34   313425         156712.5                    1393.0
# 35   620200              0.0                     443.0
# 36  1384600         692300.0                     989.0
# 37   211050          21105.0                    1568.0
# 38   951000         190200.0                    1585.0
# 39   261400         196050.0                    1307.0
# 40  1188240         237648.0                    2094.0
# 41  1756800         175680.0                    1098.0
# 42  1292300              0.0                    5599.0
# 43  5198280         519828.0                    5425.0
# 45   254500              0.0                     509.0
# 46   163110              0.0                    1494.0
# 48    65040              0.0                    1626.0
# 49  2660660              0.0                    3888.0

# %%
# 모델 적용하기
import tensorflow as tf
model = tf.keras.models.load_model('../VersionTest/multiclass_model')
predictions = model.predict(dataset)

# %%
# 후처리 테스트
result = postprocessor(predictions)
result
# Out:
# [{'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0},
#  {'AE': 0.0, 'Alliances': 0.0, 'BDR': 1.0, 'Marketing': 0.0}]
